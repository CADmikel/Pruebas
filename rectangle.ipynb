# %% [markdown]
# <a href="https://colab.research.google.com/github/CADmikel/Pruebas/blob/main/rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 'google.colab' in str(get_ipython()):
  # !pip install git+https://github.com/FullControlXYZ/fullcontrol --quiet
import fullcontrol as fc
import lab.fullcontrol as fclab
from math import tau, radians
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
origen = fc.Point(x=0,y=0,z=0)

r_fresa = 5
r = 10
a_value = 200
b_value = 250
origen = 0
depth1= 0.5

exterior_steps =[]

exterior_points =[]

exterior_points.append(fc.Point(x=origen, y=origen-r, z=depth1))
exterior_points.extend(fc.arcXY(fc.Point(x=origen+r, y=origen-r),r,0.5*tau, -0.25*tau,90))
exterior_points.append(fc.Point(x=a_value-r, y=origen, z=depth1))
exterior_points.extend(fc.arcXY(fc.Point(x=origen+a_value-r, y=origen-r),r,0.25*tau,-0.25*tau,90))
exterior_points.append(fc.Point(x=a_value, y=-b_value+r, z=depth1))
exterior_points.extend(fc.arcXY(fc.Point(x=origen+a_value-r, y=origen-b_value+r),r,0*tau,-0.25*tau,90))
exterior_points.append(fc.Point(x=a_value-r, y=-b_value, z=depth1))
exterior_points.extend(fc.arcXY(fc.Point(x=origen+r, y=origen-b_value+r),r,0.75*tau,-0.25*tau,90))
exterior_points.append(fc.Point(x=0, y=0-r, z=depth1))



exterior_steps = fclab.offset_path(exterior_points, r_fresa, flip=True, travel=True, include_original=True)


fc.transform(exterior_steps, 'plot', fc.PlotControls(style='line', zoom=0.7))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
